# %%
import argparse
import csv
import pandas as pd
from pymongo import MongoClient

def parse_arguments():
    parser = argparse.ArgumentParser(description="Script to insert data from a CSV file into a MongoDB collection")
    parser.add_argument("--mongo_uri", default="mongodb://localhost:27017/", help="MongoDB URI (default: mongodb://localhost:27017/)")
    parser.add_argument("--database", default="your_database", help="Name of the MongoDB database (default: your_database)")
    parser.add_argument("--collection", help="Name of the MongoDB collection")
    parser.add_argument("--insert", help="Path to the CSV file to insert data from")
    return parser.parse_args()
def read_csv(csv_file):
    data = []
    with open(csv_file, 'r') as file:
        reader = csv.DictReader(file)
        for row in reader:
            data.append(row)
    return data

def insert_data_mongodb(data, mongo_uri, database, collection):
    client = MongoClient(mongo_uri)
    db = client[database]
    col = db[collection]
    col.insert_many(data)
    client.close()

def main():
    args = parse_arguments()
    mongo_uri = args.mongo_uri
    database = args.database
    collection = args.collection
    csv_file = args.insert

    if not collection:
        print("Error: Please provide the name of the collection.")
        return

    if not csv_file:
        print("Error: Please provide the path to the CSV file.")
        return

    data = read_csv(csv_file)
    insert_data_mongodb(data, mongo_uri, database, collection)
    print("Data inserted into MongoDB collection successfully.")

if __name__ == "__main__":
    main()
# Out:
# usage: ipykernel_launcher.py [-h] [--mongo_uri MONGO_URI] [--database DATABASE] [--collection COLLECTION]
#                              [--insert INSERT]
# ipykernel_launcher.py: error: unrecognized arguments: -f C:\Users\stuff\AppData\Roaming\jupyter\runtime\kernel-7dc33b0a-7125-42ae-8585-d62292faabaa.json
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# D:\Users\stuff\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3513: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
import argparse
import csv
import pandas as pd
from pymongo import MongoClient

def parse_arguments():
    parser = argparse.ArgumentParser(description="Script to insert data from a CSV/Excel file into a MongoDB collection and create reports")
    parser.add_argument("--mongo_uri", default="mongodb://localhost:27017/", help="MongoDB URI (default: mongodb://localhost:27017/)")
    parser.add_argument("--database", default="your_database", help="Name of the MongoDB database (default: your_database)")
    parser.add_argument("--collection", help="Name of the MongoDB collection")
    parser.add_argument("--insert", help="Path to the CSV/Excel file to insert data from")
    parser.add_argument("--create_report", action="store_true", help="Flag to indicate creating reports")
    return parser.parse_args()

def read_data(file_path):
    if file_path.endswith('.csv'):
        return pd.read_csv(file_path, encoding='utf-8')
    elif file_path.endswith('.xlsx'):
        return pd.read_excel(file_path)
    else:
        raise ValueError("Unsupported file format. Please provide a CSV or Excel file.")


def insert_data_mongodb(data, mongo_uri, database, collection):
    client = MongoClient(mongo_uri)
    db = client[database]
    col = db[collection]
    col.insert_many(data.to_dict('records'))
    client.close()

def create_report(data):
    # Example: Creating a report based on the provided data
    # This can be customized based on specific requirements
    report = data.groupby('employee')['score'].mean()
    return report

def main():
    args = parse_arguments()
    mongo_uri = args.mongo_uri
    database = args.database
    collection = args.collection
    file_path = args.insert
    create_report_flag = args.create_report

    if not collection:
        print("Error: Please provide the name of the collection.")
        return

    if not file_path:
        print("Error: Please provide the path to the CSV/Excel file.")
        return

    data = read_data(file_path)
    insert_data_mongodb(data, mongo_uri, database, collection)
    print("Data inserted into MongoDB collection successfully.")

    if create_report_flag:
        report = create_report(data)
        print("Report:")
        print(report)

if __name__ == "__main__":
    main()
# Out:
# usage: ipykernel_launcher.py [-h] [--mongo_uri MONGO_URI] [--database DATABASE] [--collection COLLECTION]
#                              [--insert INSERT] [--create_report]
# ipykernel_launcher.py: error: unrecognized arguments: -f C:\Users\stuff\AppData\Roaming\jupyter\runtime\kernel-7dc33b0a-7125-42ae-8585-d62292faabaa.json
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# D:\Users\stuff\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3513: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
import argparse
import os
import pandas as pd
from pymongo import MongoClient

def parse_arguments():
    parser = argparse.ArgumentParser(description="Script to insert data from an Excel file into a MongoDB collection and create reports")
    parser.add_argument("--mongo_uri", default="mongodb://localhost:27017/", help="MongoDB URI (default: mongodb://localhost:27017/)")
    parser.add_argument("--database", default="your_database", help="Name of the MongoDB database (default: your_database)")
    parser.add_argument("--collection", help="Name of the MongoDB collection")
    parser.add_argument("--excel_file", help="Path to the Excel file to insert data from")
    parser.add_argument("--create_report", action="store_true", help="Flag to indicate creating reports")
    return parser.parse_args()

def read_excel_file(file_path):
    return pd.read_excel(file_path)

def insert_data_mongodb(data, mongo_uri, database, collection):
    client = MongoClient(mongo_uri)
    db = client[database]
    col = db[collection]
    col.insert_many(data.to_dict('records'))
    client.close()

def create_report(data):
    # Example: Creating a report based on the provided data
    # This can be customized based on specific requirements
    report = data.groupby('employee')['score'].mean()
    return report

def main():
    args = parse_arguments()
    mongo_uri = args.mongo_uri
    database = args.database
    collection = args.collection
    excel_file = args.excel_file
    create_report_flag = args.create_report

    if not collection:
        print("Error: Please provide the name of the collection.")
        return

    if not excel_file:
        print("Error: Please provide the path to the Excel file.")
        return

    if not os.path.isfile(excel_file):
        print("Error: The specified Excel file does not exist.")
        return

    data = read_excel_file(excel_file)
    insert_data_mongodb(data, mongo_uri, database, collection)
    print("Data inserted into MongoDB collection successfully.")

    if create_report_flag:
        report = create_report(data)
        print("Report:")
        print(report)

if __name__ == "__main__":
    main()
# Out:
# usage: ipykernel_launcher.py [-h] [--mongo_uri MONGO_URI] [--database DATABASE] [--collection COLLECTION]
#                              [--excel_file EXCEL_FILE] [--create_report]
# ipykernel_launcher.py: error: unrecognized arguments: -f C:\Users\stuff\AppData\Roaming\jupyter\runtime\kernel-7dc33b0a-7125-42ae-8585-d62292faabaa.json
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2

# %%
import pandas as pd
from pymongo import MongoClient

def clean_collections(collection1, collection2):
    unique_keys = set()
    bad_data_ids = set()

    # Retrieve data from collection1 and populate the hash set
    for document in collection1.find():
        unique_keys.add(document["_id"])

        # Validate and filter data
        if is_bad_data(document):
            bad_data_ids.add(document["_id"])

    # Retrieve data from collection2 and populate the hash set
    for document in collection2.find():
        unique_keys.add(document["_id"])

        # Validate and filter data
        if is_bad_data(document):
            bad_data_ids.add(document["_id"])

    # Deduplicate data and remove bad data
    for document in collection1.find():
        if document["_id"] in unique_keys:
            unique_keys.remove(document["_id"])
        else:
            # If the document is a duplicate or bad data, remove it from collection1
            collection1.delete_one({"_id": document["_id"]})

    for document in collection2.find():
        if document["_id"] in unique_keys:
            unique_keys.remove(document["_id"])
        else:
            # If the document is a duplicate or bad data, remove it from collection2
            collection2.delete_one({"_id": document["_id"]})

    # Remove bad data documents
    for bad_id in bad_data_ids:
        collection1.delete_one({"_id": bad_id})
        collection2.delete_one({"_id": bad_id})

# Function to validate and filter data (example implementation)
def is_bad_data(document):
    # Define a list of required fields
    required_fields = ["Test #", "Build #", "Category", "Test Case", "Expected Result", "Actual Result", "Repeatable?", "Blocker?", "Test Owner"]

    # Check if any required field is missing
    for field in required_fields:
        if field not in document:
            return True  # Document is bad if any required field is missing
    return False  # Document is not bad if all required fields are present


def main():
    # Connect to MongoDB
    client = MongoClient("mongodb://localhost:27017/")
    db = client["your_database"]
    collection1 = db["Collection1"]
    collection2 = db["Collection2"]
    
    clean_collections(collection1, collection2)
    # Read the Excel file
    excel_file = "EG4-DBDump.xlsx"
    data = pd.read_excel(excel_file)

    # Insert data into MongoDB collection
    collection2.insert_many(data.to_dict('records'))
    print("Data inserted into MongoDB collection successfully.")

    # Close MongoDB connection
    client.close()

if __name__ == "__main__":
    main()
# Out:
# Data inserted into MongoDB collection successfully.

# %%
import pandas as pd
from pymongo import MongoClient

def clean_collections(collection1, collection2):
    bad_data_ids = set()

    # Clean collection1
    for document in collection1.find():
        if is_bad_data(document):
            bad_data_ids.add(document["_id"])

    # Clean collection2
    for document in collection2.find():
        if is_bad_data(document):
            bad_data_ids.add(document["_id"])

    # Remove bad data documents
    for bad_id in bad_data_ids:
        collection1.delete_one({"_id": bad_id})
        collection2.delete_one({"_id": bad_id})

# Function to validate and filter data (example implementation)
def is_bad_data(document):
    # Define a list of required fields
    required_fields = ["Test #", "Build #", "Category", "Test Case", "Expected Result", "Actual Result", "Repeatable?", "Blocker?", "Test Owner"]

    # Check if any required field is missing
    for field in required_fields:
        if field not in document:
            return True  # Document is bad if any required field is missing
    return False  # Document is not bad if all required fields are present


def main():
    # Connect to MongoDB
    client = MongoClient("mongodb://localhost:27017/")
    db = client["your_database"]
    collection1 = db["Collection1"]  # Adjust collection names as needed
    collection2 = db["Collection2"]

    # Clean collections
    clean_collections(collection1, collection2)

    # Read the Excel file and dropna to remove empty rows
    excel_file = "EG4-DBDump.xlsx"
    data = pd.read_excel(excel_file).dropna()

    # Insert data into MongoDB collection
    collection2.insert_many(data.to_dict('records'))
    print("Data inserted into MongoDB collection successfully.")

    # Close MongoDB connection
    client.close()

if __name__ == "__main__":
    main()
# Out:
# Data inserted into MongoDB collection successfully.

# %%
from datetime import datetime
import pandas as pd
from pymongo import MongoClient

def clean_collections(collection1, collection2):
    bad_data_ids = set()

    # Clean collection1
    for document in collection1.find():
        if is_bad_data(document):
            bad_data_ids.add(document["_id"])

    # Clean collection2
    for document in collection2.find():
        if is_bad_data(document):
            bad_data_ids.add(document["_id"])

    # Remove bad data documents
    for bad_id in bad_data_ids:
        collection1.delete_one({"_id": bad_id})
        collection2.delete_one({"_id": bad_id})

# Function to validate and filter data (example implementation)
def is_bad_data(document):
    # Define a list of required fields
    required_fields = ["Test #", "Build #", "Category", "Test Case", "Expected Result", "Actual Result", "Repeatable?", "Blocker?", "Test Owner"]

    # Check if any required field is missing
    for field in required_fields:
        if field not in document:
            return True  # Document is bad if any required field is missing
    return False  # Document is not bad if all required fields are present

def list_entries_by_user(db, user_id):
    collection1 = db["Collection1"]
    collection2 = db["Collection2"]

    # Set to store unique entries
    unique_entries = set()

    # List entries for the specific user from both collections
    print(f"Unique entries for user {user_id}:")
    for collection_name, collection in [("Collection1", collection1), ("Collection2", collection2)]:
        print(f"Entries from {collection_name}:")
        for document in collection.find({"Test Owner": user_id}):
            entry_str = ", ".join([f"{key}: {value}" for key, value in document.items()])
            if entry_str not in unique_entries:
                unique_entries.add(entry_str)
                print(entry_str)
                print("-------------------------")  # Separator between documents

    # Count the number of unique entries
    count = len(unique_entries)
    
    return count



def count_blocker_and_repeater_bugs(db):
    collection1 = db["Collection1"]
    collection2 = db["Collection2"]

    # Count the number of blocker and repeater bugs
    blocker_count = 0
    repeater_count = 0
    for collection in [collection1, collection2]:
        for document in collection.find({}, {"_id": 0, "Blocker?": 1, "Repeatable?": 1}):
            if document.get("Blocker?") == "Yes":
                blocker_count += 1
            if document.get("Repeatable?") == "Yes":
                repeater_count += 1

    return blocker_count, repeater_count

def find_reports_on_build(db, build_date):
    collection1 = db["Collection1"]
    collection2 = db["Collection2"]

    # Convert input date to a datetime object
    formatted_build_date = datetime.strptime(build_date, "%m/%d/%Y").date()

    # Print formatted build date
    print("Formatted build date:", formatted_build_date)

    # Retrieve all reports on the specified build date from both collections (no duplicates)
    print(f"Entries on build date {build_date}:")
    for collection_name, collection in [("Collection1", collection1), ("Collection2", collection2)]:
        print(f"Entries from {collection_name}:")
        for document in collection.find():
            # Check if the "Build #" field is a datetime object and compare the date part
            if isinstance(document.get("Build #"), datetime) and document.get("Build #").date() == formatted_build_date:
                # Print the document
                print(document)
                print("-------------------------")  # Separator between documents

def get_first_middle_last_test_cases(db):
    collection2 = db["Collection2"]

    # Retrieve all test cases from collection 2
    test_cases = []
    for document in collection2.find({}, {"_id": 0, "Test #": 1}):
        test_cases.append(document["Test #"])

    # Find the first, middle, and last test cases
    first_test_case = test_cases[0]
    middle_test_case = test_cases[len(test_cases) // 2]  # Determine the middle test case
    last_test_case = test_cases[-1]

    return first_test_case, middle_test_case, last_test_case

def main():
    # Connect to MongoDB
    client = MongoClient("mongodb://localhost:27017/")
    db = client["your_database"]
    collection1 = db["Collection1"]  # Adjust collection names as needed
    collection2 = db["Collection2"]

    # Clean collections
    clean_collections(collection1, collection2)

    # Read the Excel file and dropna to remove empty rows
    excel_file = "EG4-DBDump.xlsx"
    data = pd.read_excel(excel_file).dropna()

    # Insert data into MongoDB collection
    collection2.insert_many(data.to_dict('records'))
    print("Data inserted into MongoDB collection successfully.")
    
    userId = "Kevin Chaja"
    user_entries = list_entries_by_user(db,userId)
    print("Entries for user", userId, ":", user_entries)

    blocker_count, repeater_count = count_blocker_and_repeater_bugs(db)
    print("Number of blocker bugs:", blocker_count)
    print("Number of repeater bugs:", repeater_count)

    reports_on_build = find_reports_on_build(db, "3/19/2024")
    print("Reports on build date: ", reports_on_build)

    first_test_case, middle_test_case, last_test_case = get_first_middle_last_test_cases(db)
    print("First test case: ", first_test_case)
    print("Middle test case: ", middle_test_case)
    print("Last test case: ", last_test_case)

    # Close MongoDB connection
    client.close()

if __name__ == "__main__":
    main()
# Out:
# Data inserted into MongoDB collection successfully.
# Unique entries for user Kevin Chaja:
# Entries from Collection1:
# Entries from Collection2:
# _id: 660ccd3ac0d474b140be2629, Test #: 1, Build #: 2024-03-18 00:00:00, Category: UI, Test Case: Bug: Settings, Expected Result: Close settings tab when hitting the x button, Actual Result: Would not close, Repeatable?: Yes, Blocker?: No, Test Owner: Kevin Chaja
# -------------------------
# _id: 660ccd3ac0d474b140be262a, Test #: 2, Build #: 2024-03-18 00:00:00, Category: UI, Test Case: Bug: Adventure mode, Expected Result: Play adventure mode, Actual Result: Still does not atleast let you leave the mode to go back to main menu even though it does not work currently, Repeatable?: Yes, Blocker?: Yes, Test Owner: Kevin Chaja
# -------------------------
# _id: 660ccd3ac0d474b140be262b, Test #: 3, Build #: 2024-03-18 00:00:00, Category: UI, Test Case: Bug: Tutorial coins, Expected Result: Show that you receive the coins/ indicator of the amount of coins you have, Actual Result: Nothing to show anywhere in the menu other that the tutorial says you have completed it, Repeatable?: No, Blocker?: No, Test Owner: Kevin Chaja
# -------------------------
# _id: 660ccd3ac0d474b140be26fe, Test #: 0, Build #: 2024-03-16 00:00:00, Category: Adventure, Test Case: clicking on back icon, Expected Result: take me to home page, Actual Result: nothing, Repeatable?: yes, Blocker?: no, Test Owner: Kevin Chaja
# -------------------------
# _id: 660ccd3ac0d474b140be26ff, Test #: 1, Build #: 2024-03-16 00:00:00, Category: Adventure/ Select, Test Case: click on level, Expected Result: show me level objective, Actual Result: nothing, Repeatable?: yes, Blocker?: no, Test Owner: Kevin Chaja
# -------------------------
# _id: 660ccd3ac0d474b140be2700, Test #: 2, Build #: 2024-03-16 00:00:00, Category: Adventure/ Select, Test Case: click on deck builder, Expected Result: take me to deck builder, Actual Result: nothing, Repeatable?: yes, Blocker?: no, Test Owner: Kevin Chaja
# -------------------------
# _id: 660ccd3ac0d474b140be281f, Test #: 1, Build #: 2024-03-08 00:00:00, Category: Authenticating, Test Case: Stuck on Authentication, Expected Result: Expected to authenticate me, Actual Result: It got stuck on the authenticating page, Repeatable?: no, Blocker?: Yes, Test Owner: Kevin Chaja
# -------------------------
# _id: 660ccd3ac0d474b140be2820, Test #: 2, Build #: 2024-03-08 00:00:00, Category: Log in, Test Case: high volume of users, Expected Result: Expected to log in after authentication, Actual Result: pop up error: Due to the high volume of users not able to process, Repeatable?: no, Blocker?: Yes, Test Owner: Kevin Chaja
# -------------------------
# _id: 660ccd3ac0d474b140be2821, Test #: 3, Build #: 2024-03-08 00:00:00, Category: Log in, Test Case: log in loading, Expected Result: Expected to log in, Actual Result: It got stuck in loging in page, Repeatable?: yes, Blocker?: yes, Test Owner: Kevin Chaja
# -------------------------
# _id: 660ccd3ac0d474b140be28a0, Test #: 1, Build #: 2024-02-27 00:00:00, Category: Login/UI/Game/FindMatch  Login/UI/Game/training, Test Case: Bug: Whenever I try to find a match online or go to the training, the game does not load into the game, and is just stuck loading the match, Expected Result: I would get in a match, Actual Result: The game does not load into the match, Repeatable?: Yes, Blocker?: Yes, Test Owner: Kevin Chaja
# -------------------------
# _id: 660ccd3ac0d474b140be28a1, Test #: 2, Build #: 2024-02-25 00:00:00, Category: Login/UI/Game/Build Deck, Test Case: User case: As a user, when I went to go build a deck, I found the UI kind of confusing at first. I didn't really know how much cards has to be in a deck and first time I built a deck, I didn't know I had to have it saved and selected before finding a match.  Took a little bit of playing with, but I understand how it works now., Expected Result: I kind of expected at first when I build a deck, it would show the number of cards I have in the deck as well as expecting a drag and drop system for building decks. I also expected that the deck would automatically save when I exit, or at least a pop up reminder to save., Actual Result: In order to build a deck, users have to selected a card and a menu pops up prompting the user to add or remove card. If the user adds, they must exit the card menu and the card will then be displayed in the deck. There are no indicators on how much cards there needs to be in the deck. The only indicator will appear when you save a deck and the menu tells you that you don't have enough cards and tells you how many more cards are needed. When saving a deck, you must name it and it is only after you exit the build deck menu where you gotta select the deck you want to use when you play a game, Repeatable?: Yes, Blocker?: No, Test Owner: Kevin Chaja
# -------------------------
# _id: 660ccd3ac0d474b140be28a2, Test #: 3, Build #: 2024-02-25 00:00:00, Category: Login/UI/Game/Tutorial, Test Case: Bug?: After completing the tutorial, I went back to play it again. However, it seems that the tutorial acts as a training ground however, you only have limited amount of cards, leading to a point during the game where both the players and the AI have no cards meaning both cannot draw new ones. If the AI runs out of cards and doesn't have any cards to draw, the AI opponent is stuck in the drawing phase and rather than switching turns,the AI just stays and waits the entire turn. The player must wait until the opponents turn is over, and is either stuck doing nothing or attacks the enemy only to switch turns and wait until the enemy's timer to finish to switch to their turn., Expected Result: I was expecting to get more cards in the tutorial instead of a limited amount rather than having to wait for the opponents clock to finish because they also can't draw any cards, Actual Result: I had to wait the entire opponents turn to make a move cause they didn't want to skip, Repeatable?: Yes, Blocker?: No, Test Owner: Kevin Chaja
# -------------------------
# _id: 660ccd3ac0d474b140be28a3, Test #: 4, Build #: 2024-02-27 00:00:00, Category: Login/UI/Game/Friends, Test Case: Bug? Whenever I ask friend to battle, and they accept, the game loads in, but logs both of us out, Expected Result: Expecting to play with a friend, Actual Result: I couldn't get a game and it always logged both of us out, Repeatable?: Yes, Blocker?: Yes, Test Owner: Kevin Chaja
# -------------------------
# _id: 660ccd3ac0d474b140be29a8, Test #: 1, Build #: 2024-02-24 00:00:00, Category: UI, Test Case: x button for settings popup window on main page does not work, Expected Result: the popup closes, similar to "Cancel" button behavior, Actual Result: nothing, Repeatable?: yes, Blocker?: no, Test Owner: Kevin Chaja
# -------------------------
# _id: 660ccd3ac0d474b140be29a9, Test #: 2, Build #: 2024-02-24 00:00:00, Category: Main Page, Test Case: annoying news popup, Expected Result: should only be opened when there is a new update user has not seen or at least only once a day, Actual Result: pops up every time you're on main page, Repeatable?: yes, Blocker?: no, Test Owner: Kevin Chaja
# -------------------------
# _id: 660ccd3ac0d474b140be29aa, Test #: 3, Build #: 2024-02-24 00:00:00, Category: Game, Test Case: inaccessible deck builder tutorial, Expected Result: deck builder tutorial is played, Actual Result: nothing, Repeatable?: yes, Blocker?: yes, Test Owner: Kevin Chaja
# -------------------------
# _id: 660ccd3ac0d474b140be29ab, Test #: 4, Build #: 2024-02-24 00:00:00, Category: Login, Test Case: annoying login procedure, Expected Result: login should persist on the same environment for considerable time, Actual Result: you must login using the off-tab with multiple authorizations back to back every time you want to launch the game, Repeatable?: yes, Blocker?: no, Test Owner: Kevin Chaja
# -------------------------
# _id: 660ccd3ac0d474b140be29ac, Test #: 5, Build #: 2024-02-24 00:00:00, Category: Game, Test Case: "set" cards with "flip" effect, when activated during enemy turn, stops match, Expected Result: "flip" effect plays, and enemy turn continues, Actual Result: game stops, Repeatable?: yes, Blocker?: yes, Test Owner: Kevin Chaja
# -------------------------
# _id: 660ccd3ac0d474b140be29ad, Test #: 6, Build #: 2024-02-24 00:00:00, Category: UI, Test Case: "exit tutorial" button persists into non-tutorial games, Expected Result: it only shows on tutorials and nowhere else, Actual Result: the button persists in normal games, and functions as a surrender button, Repeatable?: yes, Blocker?: no, Test Owner: Kevin Chaja
# -------------------------
# _id: 660ccd3ac0d474b140be29ae, Test #: 7, Build #: 2024-02-24 00:00:00, Category: UI, Test Case: deckbuilder doesn't allow you to add to deck without "opening up" the card in its "detailed mode", Expected Result: if user is sufficiently informed about their cards, they should be able to quickly add them to deck without going into the detailed card UI, Actual Result: you must use the "card details" UI to add cards to deck, Repeatable?: yes, Blocker?: no, Test Owner: Kevin Chaja
# -------------------------
# _id: 660ccd3ac0d474b140be29df, Test #: 1, Build #: 2024-02-25 00:00:00, Category: Main Page, Test Case: A frozen screen, Expected Result: Expected to leave online players list back to main screen and it all froze, Actual Result: Frozen, Repeatable?: Yes, Blocker?: Yes, Test Owner: Kevin Chaja
# -------------------------
# _id: 660ccd3ac0d474b140be29e0, Test #: 2, Build #: 2024-02-25 00:00:00, Category: Login, Test Case: Logged out, Expected Result: Expected to stay logged in after refreshing and completely logged out, Actual Result: Had to login again, Repeatable?: Yes, Blocker?: Yes, Test Owner: Kevin Chaja
# -------------------------
# Entries for user Kevin Chaja : 22
# Number of blocker bugs: 171
# Number of repeater bugs: 296
# Formatted build date: 2024-03-19
# Entries on build date 3/19/2024:
# Entries from Collection1:
# Entries from Collection2:
# {'_id': ObjectId('660ccd3ac0d474b140be25ee'), 'Test #': 1, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Adventure Select Screen', 'Test Case': 'User clicked on the Adventures button from the main menu options.', 'Expected Result': 'User is able to click on the icons and buttons present on the screen.', 'Actual Result': 'Nothing happens when user clicks on the Book and House icons in the upper right corner, or on the Deck Builder button in the lower left corner.', 'Repeatable?': 'Yes', 'Blocker?': 'No', 'Test Owner': 'Yana Zaynullina'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be25ef'), 'Test #': 2, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Adventure Select Screen', 'Test Case': 'User clicked on the Adventures button from the main menu options.', 'Expected Result': 'User is able to click on the icons and buttons present on the screen.', 'Actual Result': 'Nothing happens when user clicks on the Back button to return to the main menu.', 'Repeatable?': 'Yes', 'Blocker?': 'Yes', 'Test Owner': 'Yana Zaynullina'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be25f0'), 'Test #': 3, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Adventure Select Screen', 'Test Case': 'User clicked on the Adventures button from the main menu options. Once there, user clicks on one of the level selection bubbles on the map to start the adventure. It opens another sliding screen from the right.', 'Expected Result': 'User is able to click on the icons and buttons present on the screen.', 'Actual Result': 'Nothing happens when user clicks on the Play button to start the adventure.', 'Repeatable?': 'Yes', 'Blocker?': 'Yes', 'Test Owner': 'Yana Zaynullina'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be25f1'), 'Test #': 4, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Main Page | Settings', 'Test Case': 'User clicked on the Settings button from the main menu. It opened a new pop-up screen in the middle of the screen with settings.', 'Expected Result': 'User is able to close the window by clicking on the X button.', 'Actual Result': 'Nothing happens when user clicks on the X button.', 'Repeatable?': 'Yes', 'Blocker?': 'No', 'Test Owner': 'Yana Zaynullina'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be2607'), 'Test #': 1, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Playing the game', 'Test Case': 'Bug', 'Expected Result': 'I expect to be able to attack my opponenect at the proper phase', 'Actual Result': 'The game skips over phases and does not allow me to attack my opponent', 'Repeatable?': 'Yes', 'Blocker?': 'No', 'Test Owner': 'Mirna Farahat'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be2608'), 'Test #': 2, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Tutorial', 'Test Case': 'Bug', 'Expected Result': 'I expect to be able to go through the tutorial and finish a complete turn', 'Actual Result': 'The tutorial froze and was not allowing me to draw any cards', 'Repeatable?': 'Yes', 'Blocker?': 'No', 'Test Owner': 'Mirna Farahat'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be2609'), 'Test #': 3, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Tutorial', 'Test Case': 'User Case', 'Expected Result': 'I expect clear instructions and guidance on how to properly play the game', 'Actual Result': 'The tutorial does not provide clear step-by-step instructions on how to properly play the game', 'Repeatable?': 'Yes', 'Blocker?': 'No', 'Test Owner': 'Mirna Farahat'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be260a'), 'Test #': 4, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Accessing the game', 'Test Case': 'Bug', 'Expected Result': 'I expect that when I click on "Arena" I can start playing the game.', 'Actual Result': 'When I click "Arena" there is a dim screen displayed that does not display any additional "features" of the game.', 'Repeatable?': 'Yes', 'Blocker?': 'Yes', 'Test Owner': 'Mirna Farahat'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be260b'), 'Test #': 5, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Trying to play the game', 'Test Case': 'Bug', 'Expected Result': 'I expect that the game functions flawlessly without any glitches', 'Actual Result': 'When I clicked on "Arena" there was a sudden glitch that showed the AI player repeatedly putting down the same card in the same spot', 'Repeatable?': 'No', 'Blocker?': 'Yes', 'Test Owner': 'Mirna Farahat'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be2610'), 'Test #': 0, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Gameplay Tutorial', 'Test Case': 'Bug: After clicking the cards when it was not my turn, a black overlay appeared and did not close so I was unable to click the draw card button', 'Expected Result': 'I expected the draw button to be clickable when I was required to click it', 'Actual Result': 'A black overlay appeared after clicking on cards and their options when it was not my turn and I was unable to click the draw button to progress the tutorial', 'Repeatable?': 'Yes', 'Blocker?': 'Yes', 'Test Owner': 'Katrina Ortiz'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be2611'), 'Test #': 1, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Deck Builder Tutorial', 'Test Case': 'Bug: If you click on NFTs section and then attempt to complete the task where you need to add 20 Guardians to the deck but don\'t have enough cards, you cannot exit out to pick the other section "Free to Use" to be able to add more cards', 'Expected Result': 'I expected to be able to exit out of the NFTs section to navigate to the "Free to Use" section to add more cards', 'Actual Result': 'Since there were not enough cards in the NFTs section of the Deck Builder Tutorial when adding cards to my deck, I was unable to exit and navigate to the "Free to Use" section and progress the tutorial', 'Repeatable?': 'Yes', 'Blocker?': 'Yes', 'Test Owner': 'Katrina Ortiz'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be2612'), 'Test #': 2, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Deck Builder Tutorial', 'Test Case': 'Bug: There is no way to exit the Deck Builder Tutorial', 'Expected Result': 'I expected there to be a way to exit the Deck Builder Tutorial like there is for the Gameplay Tutorial', 'Actual Result': 'There is no way to exit the Deck Builder Tutorial and a refresh is required to get out', 'Repeatable?': 'Yes', 'Blocker?': 'Yes', 'Test Owner': 'Katrina Ortiz'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be2613'), 'Test #': 3, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Leaderboard', 'Test Case': 'Bug: The statistics for the rankings wraps and overlaps the labels at the bottom of the leaderboard', 'Expected Result': 'I expected the text and statistics to be formatted where they do not overlap', 'Actual Result': 'The statistics for the rankings overlaps the text labels at the bottom of the leaderboard', 'Repeatable?': 'Yes', 'Blocker?': 'No', 'Test Owner': 'Katrina Ortiz'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be2614'), 'Test #': 4, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Leaderboard', 'Test Case': 'Bug: Since the Wins and Losses are already labelled, I do not think we need the "W" or "L" after the number', 'Expected Result': 'The information presented is concise', 'Actual Result': 'Since the Wins and Losses are already labelled, the "W" and "L" after the number is redunant', 'Repeatable?': 'Yes', 'Blocker?': 'No', 'Test Owner': 'Katrina Ortiz'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be2615'), 'Test #': 5, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Leaderboard', 'Test Case': 'Bug: The numbers are inconsistently spaced for the information at the bottom of the Leaderboard', 'Expected Result': 'I expected the numbers to be spaced consistently', 'Actual Result': 'The numbers are spaced inconsistently in the fields that are presented at the bottom of the Leaderboard (i.e. The number after the colon after "Level" has a space while the numbers after "Wins" and "Losses" do not)', 'Repeatable?': 'Yes', 'Blocker?': 'No', 'Test Owner': 'Katrina Ortiz'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be2616'), 'Test #': 6, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Leaderboard', 'Test Case': 'Bug: When you reach page 100, the numbers stack and are not formatted nicely', 'Expected Result': 'I expected the page numbers to stay formatted when it reaches 100 and above', 'Actual Result': 'The page numbers start not formatting correctly when it reaches 100 and above', 'Repeatable?': 'Yes', 'Blocker?': 'No', 'Test Owner': 'Katrina Ortiz'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be2617'), 'Test #': 7, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Leaderboard', 'Test Case': 'Bug: The button to clear the search field does not clear the search input field', 'Expected Result': 'I expected the button to clear the search input field to actually clear the input field when pressed', 'Actual Result': 'The button to clear the search input field did not clear the input field when pressed', 'Repeatable?': 'Yes', 'Blocker?': 'No', 'Test Owner': 'Katrina Ortiz'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be2618'), 'Test #': 8, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Settings', 'Test Case': 'Bug: Changing the language from English to another language only changes some text to that selected language but not all text', 'Expected Result': 'I expected all English text to change to the selected language', 'Actual Result': 'Some text stayed English even when the language was changed (i.e. The options in the Settings changed to the selected language but the title "Settings" remained in English)', 'Repeatable?': 'Yes', 'Blocker?': 'No', 'Test Owner': 'Katrina Ortiz'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be2619'), 'Test #': 9, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Settings', 'Test Case': 'Bug: The default volumes were set at 60 initially but when the "Reset to default" button was clicked, the new default was 50', 'Expected Result': 'I expected the volume options presets to be the same default (60) initially and when the "Reset to default" was pressed', 'Actual Result': 'The volume presets were 60 initially and then changed to 50 when the "Reset to default" button was pressed', 'Repeatable?': 'Yes', 'Blocker?': 'No', 'Test Owner': 'Katrina Ortiz'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be261a'), 'Test #': 10, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Arena', 'Test Case': 'Bug: The numbers after the word "Gold" when viewing a card\'s details are not spaced after the colon', 'Expected Result': 'I expected the numbers to be spaced consistently', 'Actual Result': 'The numbers after the colon in the word "Gold" are not spaced', 'Repeatable?': 'Yes', 'Blocker?': 'No', 'Test Owner': 'Katrina Ortiz'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be2621'), 'Test #': 0, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Login', 'Test Case': 'Login page stuck at "Login in with email" when you close the tab that opens up after pressing login with email', 'Expected Result': 'Give the user a choice to use Wallet Login or Email Login', 'Actual Result': 'Stuck on login page saying "Login with email"', 'Repeatable?': 'yes', 'Blocker?': 'yes', 'Test Owner': 'Elijah Ko'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be2622'), 'Test #': 1, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'UI', 'Test Case': 'Blue frame that highlights creation of new deck is misplaced', 'Expected Result': 'Blue highlighting during tutorial highlights the creation button', 'Actual Result': 'Most of the blue highlighting is off the button', 'Repeatable?': 'yes', 'Blocker?': 'no', 'Test Owner': 'Elijah Ko'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be2623'), 'Test #': 2, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'UI', 'Test Case': 'Words in different language are being split in different lines (Tutorial prompt)', 'Expected Result': 'Words are not separated into two lines', 'Actual Result': 'Word split into half - one in first line, the other in second', 'Repeatable?': 'yes', 'Blocker?': 'no', 'Test Owner': 'Elijah Ko'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be2624'), 'Test #': 3, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'UI', 'Test Case': 'Pressing the back arrow in adventure does not do anything', 'Expected Result': 'Going back to main page', 'Actual Result': 'Nothing happens', 'Repeatable?': 'yes', 'Blocker?': 'yes', 'Test Owner': 'Elijah Ko'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be2625'), 'Test #': 4, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'UI', 'Test Case': 'Pressing the home icon in adventure does not do anything', 'Expected Result': 'Going back to main page', 'Actual Result': 'Nothing happens', 'Repeatable?': 'yes', 'Blocker?': 'yes', 'Test Owner': 'Elijah Ko'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be262c'), 'Test #': 1, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Battle', 'Test Case': 'User Case', 'Expected Result': 'Be able to read the card details after using them in battle.', 'Actual Result': 'Can only see the list of cards used in battle but not the card details.', 'Repeatable?': 'Y', 'Blocker?': 'N', 'Test Owner': 'Peter Hernandez'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be262d'), 'Test #': 2, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Battle', 'Test Case': 'User Case', 'Expected Result': "When a Fire Croc's card activation event occurs during battle, the AI waits for the User to select an option then proceeds with their turn.", 'Actual Result': "When Fire Croc's card activation prompt popped up, the AI kept attacking before I chose an option.", 'Repeatable?': 'Y', 'Blocker?': 'N', 'Test Owner': 'Peter Hernandez'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be262e'), 'Test #': 3, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Battle', 'Test Case': 'Fire Croc Counter Attack prompt bug', 'Expected Result': 'Two Fire Crocs on the field, one died and prompt comes up. Second died before choosing an option on prompt one, but still able to use the card effect of the second Fire Croc.', 'Actual Result': "When the first Fire Croc's Counter prompt popped up and the second one died before choosing an option, the turn ended without registering the second Fire Croc counter.", 'Repeatable?': 'Y', 'Blocker?': 'N', 'Test Owner': 'Peter Hernandez'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be262f'), 'Test #': 1, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'main page', 'Test Case': 'bug: Still cannot exit adventure screen', 'Expected Result': 'exit adventure screen', 'Actual Result': 'stuck in screen until reload of page', 'Repeatable?': 'yes', 'Blocker?': 'yes', 'Test Owner': 'Michael Green'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be2630'), 'Test #': 2, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'game', 'Test Case': 'bug: player chosen icon resets to default in match', 'Expected Result': 'player selected icon shown in game', 'Actual Result': 'default player icon shown instead', 'Repeatable?': 'yes', 'Blocker?': 'no', 'Test Owner': 'Michael Green'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be2631'), 'Test #': 3, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'game', 'Test Case': 'user case: games take too much time due to small starting hand', 'Expected Result': 'games take resonable amount of time', 'Actual Result': 'because of base hand size, all cards are played within two turns, resulting in a slowdown', 'Repeatable?': 'yes', 'Blocker?': 'no', 'Test Owner': 'Michael Green'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be2632'), 'Test #': 4, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'game', 'Test Case': 'user case: font color of health hard to see', 'Expected Result': 'see enemy health', 'Actual Result': 'when health drops below 30% cannot see exact numbers', 'Repeatable?': 'yes', 'Blocker?': 'no', 'Test Owner': 'Michael Green'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be2633'), 'Test #': 5, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'game', 'Test Case': 'bug: Zalla card targeted by enemy despite having a second guardian on the field', 'Expected Result': 'card passive would prevent targeting of card', 'Actual Result': 'Zalla was targeted and attacked', 'Repeatable?': 'yes', 'Blocker?': 'no', 'Test Owner': 'Michael Green'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be2634'), 'Test #': 1, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Game', 'Test Case': 'bug: I got disconnected from the servers', 'Expected Result': 'Play the game', 'Actual Result': 'Got disconected in the middle of the game', 'Repeatable?': 'no', 'Blocker?': 'Yes', 'Test Owner': 'Jorge Torrez'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be2635'), 'Test #': 2, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Main Page', 'Test Case': 'bug: I just clicked adventure and its not letting me play and do anything', 'Expected Result': 'Play adventure', 'Actual Result': 'It locked me in the adventure map', 'Repeatable?': 'yes', 'Blocker?': 'yes', 'Test Owner': 'Jorge Torrez'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be2636'), 'Test #': 3, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Login', 'Test Case': 'bug: I couldnt acces the game, it kept asking for authentification', 'Expected Result': 'Access the game', 'Actual Result': 'Not able to login', 'Repeatable?': 'yes', 'Blocker?': 'yes', 'Test Owner': 'Jorge Torrez'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be263e'), 'Test #': 1, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Login/UI/Game/Main Page/Settings', 'Test Case': "bug: When heading over to the settings page and clicking to adjust the volumes, it stays the same. User case: volume should change as it's increased or decreasd but it doesn't", 'Expected Result': 'The volume should go up or down based on what you toggle it to', 'Actual Result': 'volume stays the same', 'Repeatable?': 'no', 'Blocker?': 'no', 'Test Owner': 'Edward Shatverov'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be263f'), 'Test #': 2, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Login/UI/Game/Main Page/Settings', 'Test Case': "bug: When trying to change the language, it changes the language but some of the display buttons aren't changed such as arena, adventures, tutorials, nft shops, settings. user case: When language is changed, it does not change everything on the main page.", 'Expected Result': 'the sidebar and menu options should change when the language is changed', 'Actual Result': 'Only some of the options are changed, and not all', 'Repeatable?': 'no', 'Blocker?': 'no', 'Test Owner': 'Edward Shatverov'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be2640'), 'Test #': 0, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Login/UI/Game/Arena', 'Test Case': 'Bug: There is a add(+) button in the messages when you play the arena and it does nothing', 'Expected Result': 'I was expecting the button to mainley send the message or add emotes or something', 'Actual Result': 'Nothing happens when you click that button', 'Repeatable?': 'yes', 'Blocker?': 'no', 'Test Owner': 'Omar Garcia'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be2641'), 'Test #': 1, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Login/UI/Game/Main menu', 'Test Case': "Bug?: When you adjust the volume, it won't change until you save but that wasn't the case when you hit default", 'Expected Result': "I was expecting that when you change the options for the game, the volume would adjust accordingly with the sound bar. On the other hand, if the audio doesn't apply until after the user saves, I was expecting the default options to have the same treatment.", 'Actual Result': "When you adjust audio for game in the soundbar, volume doesn't apply until the user saves, but when a user reverts to default, the volume will apply immediately before the user saves option.", 'Repeatable?': 'Yes', 'Blocker?': 'no', 'Test Owner': 'Omar Garcia'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be2642'), 'Test #': 2, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Login/UI/Game/Tutorials', 'Test Case': "Bug: Search feature doesn't function properly in tutorial", 'Expected Result': 'When I go to the search bar in the tutorial, I was expecting the search to filter out the results by the one I am looking for', 'Actual Result': "When I searched a tutorial, It didn't return any filtered results and the screen just remained the same as it did when I arrived at the screen.", 'Repeatable?': 'Yes', 'Blocker?': 'Yes', 'Test Owner': 'Omar Garcia'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be2643'), 'Test #': 3, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Login/UI/Game', 'Test Case': "Bug: The delete (x) button doesn't work anywhere", 'Expected Result': 'When I type something in the search bar for tutorial or to find friends, I expect that when I hit the delete (x) button,it would clear my entry in the search bar', 'Actual Result': 'When I actually press the delete (x) button, it does not anything.', 'Repeatable?': 'Yes', 'Blocker?': 'Yes', 'Test Owner': 'Omar Garcia'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be2644'), 'Test #': 1, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Game', 'Test Case': 'Bug: Adventure mode does not seem to be working, can enter the UI but once loaded, nothing works', 'Expected Result': 'Start a battle', 'Actual Result': 'UI buttons not working', 'Repeatable?': 'Yes', 'Blocker?': 'Yes', 'Test Owner': 'Ryan Kao'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be2645'), 'Test #': 2, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Login', 'Test Case': 'user case: Having complications with signing in, had very long loading', 'Expected Result': 'Verification process succeeds', 'Actual Result': 'Be able to load into game', 'Repeatable?': 'no', 'Blocker?': 'Yes', 'Test Owner': 'Ryan Kao'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be2646'), 'Test #': 3, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Game', 'Test Case': 'User case: Game would freeze midway and would have to refresh browser', 'Expected Result': 'Battle opponent', 'Actual Result': 'Froze requiring a restart', 'Repeatable?': 'no', 'Blocker?': 'Yes', 'Test Owner': 'Ryan Kao'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be2648'), 'Test #': 1, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Game', 'Test Case': 'bug: At about 10 cards left game got stuck, can not continue', 'Expected Result': 'End turn and proceed with the game', 'Actual Result': 'Timer not working and cannot end my turn to proceed', 'Repeatable?': 'yes', 'Blocker?': 'yes', 'Test Owner': 'Jonathan Alcantar'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be2649'), 'Test #': 2, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Game', 'Test Case': 'bug: After playing a game, and stating a new one, I cannot make any moves', 'Expected Result': 'Be able to make moves like draw a card or make an attack', 'Actual Result': 'The timer goes on but cannot make any moves', 'Repeatable?': 'yes', 'Blocker?': 'yes', 'Test Owner': 'Jonathan Alcantar'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be264a'), 'Test #': 3, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Game', 'Test Case': "user case: The timers for each player's turn are too long", 'Expected Result': 'Make the timers shorter', 'Actual Result': 'Timers are too long', 'Repeatable?': 'yes', 'Blocker?': 'no', 'Test Owner': 'Jonathan Alcantar'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be264e'), 'Test #': 1, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'main page', 'Test Case': 'user case: multiple windows overlapping(I pressed leader board and then setting)', 'Expected Result': 'setting windows should be in the front because I was tapping on it, at least the leader board window should go away', 'Actual Result': 'the leader board was in the front and the setting window was covered by it', 'Repeatable?': 'yes', 'Blocker?': 'no', 'Test Owner': 'Hannah Xie'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be264f'), 'Test #': 2, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'main page', 'Test Case': 'user case: player frame/player title/player banner unclickable', 'Expected Result': 'pop up a window to change player frame/title/banner', 'Actual Result': 'nothing showed up', 'Repeatable?': 'yes', 'Blocker?': 'no', 'Test Owner': 'Hannah Xie'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be2650'), 'Test #': 3, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'main page', 'Test Case': "user case: volume button doesn't change when adjusting it, it only changes after you save it (you wouldn't be able to know how much volume for '42' would be before you save it)", 'Expected Result': 'volume changes as you are sliding the volume bar', 'Actual Result': "volume doesn't change, it is still the old volume before you save it", 'Repeatable?': 'yes', 'Blocker?': 'no', 'Test Owner': 'Hannah Xie'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be2651'), 'Test #': 1, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Arena Game', 'Test Case': 'Trying to attack with a duplicate card', 'Expected Result': 'Being able to attack with both individual cards', 'Actual Result': 'Once 1 was used for an attack cant use the other', 'Repeatable?': 'yes', 'Blocker?': 'no', 'Test Owner': 'Armen Levonyan'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be2652'), 'Test #': 2, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Arena Game', 'Test Case': 'Accidentally clicking to a different link while in the middle of a game', 'Expected Result': 'Be able to return to the Arena game I was in', 'Actual Result': 'Back to the main menu', 'Repeatable?': 'yes', 'Blocker?': 'no', 'Test Owner': 'Armen Levonyan'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be2653'), 'Test #': 3, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Adventure Game', 'Test Case': 'Going to adventure to play 1-1 for The Kingdom', 'Expected Result': 'Start the game, use 3 Energy', 'Actual Result': 'Button gives visual indicator that its being clicked but nothing changes', 'Repeatable?': 'yes', 'Blocker?': 'yes', 'Test Owner': 'Armen Levonyan'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be2654'), 'Test #': 1, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'UI', 'Test Case': 'Leaderboard search doesn’t work', 'Expected Result': 'Typing in a username returns revelant user stats', 'Actual Result': 'Search does not return anything', 'Repeatable?': 'yes', 'Blocker?': 'no', 'Test Owner': 'Randy Herrera'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be2655'), 'Test #': 2, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'UI', 'Test Case': 'Cannot cancel matchmaking', 'Expected Result': 'Clicking “cancel” during matchmaking stops queue', 'Actual Result': 'Clicking “cancel” does nothing', 'Repeatable?': 'yes', 'Blocker?': 'no', 'Test Owner': 'Randy Herrera'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be2656'), 'Test #': 3, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Game', 'Test Case': 'Fire Croc ability freezes game', 'Expected Result': 'Fire Croc deals 50 damage to enemy card when destroyed', 'Actual Result': 'Ability works, but game freezes after damage is dealt', 'Repeatable?': 'yes', 'Blocker?': 'no', 'Test Owner': 'Randy Herrera'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be2657'), 'Test #': 4, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'UI', 'Test Case': 'Leaderboard page number odd formatting', 'Expected Result': 'Leaderboard page 1234 should show as a single number', 'Actual Result': 'Page 1234 is separated by a new line, 12 and then 34.', 'Repeatable?': 'yes', 'Blocker?': 'no', 'Test Owner': 'Randy Herrera'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be2658'), 'Test #': 5, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Game', 'Test Case': 'Hired cards not show sometimes', 'Expected Result': 'Clicking “Hire” for a card places it on the battlefield', 'Actual Result': 'Hiring Fire Croc twice does not place the second Croc on field', 'Repeatable?': 'no', 'Blocker?': 'no', 'Test Owner': 'Randy Herrera'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be2667'), 'Test #': 1, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'UI', 'Test Case': 'bug: adventure -> home, deck builder, back', 'Expected Result': 'the buttons to work correctly', 'Actual Result': 'the buttons does not work, and I have to close the window and restart again', 'Repeatable?': 'yes', 'Blocker?': 'yes', 'Test Owner': 'Yashira Almanza'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be2668'), 'Test #': 2, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'main page', 'Test Case': 'bug: tutorials -> complete-> pop-up', 'Expected Result': 'check the "complete the tasks" box and continue', 'Actual Result': 'the box does not check, and does not let me move on', 'Repeatable?': 'yes', 'Blocker?': 'yes', 'Test Owner': 'Yashira Almanza'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be2669'), 'Test #': 4, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'login', 'Test Case': 'bug: metamask button does not work', 'Expected Result': 'take me to some portal', 'Actual Result': 'does not take me anymore', 'Repeatable?': 'no', 'Blocker?': 'no', 'Test Owner': 'Yashira Almanza'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be266a'), 'Test #': 1, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Login/Settings', 'Test Case': 'Clicking the X button doesnt do anything', 'Expected Result': 'Close the window', 'Actual Result': 'Nothing happens and X is no longer available to use', 'Repeatable?': 'yes', 'Blocker?': 'No', 'Test Owner': 'Jorge Enriquez'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be266b'), 'Test #': 2, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Login/Adventure', 'Test Case': 'Home button does not work', 'Expected Result': 'Return to the main menu', 'Actual Result': 'Nothing happens', 'Repeatable?': 'yes', 'Blocker?': 'Yes', 'Test Owner': 'Jorge Enriquez'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be266c'), 'Test #': 3, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Login/News', 'Test Case': 'User Case: clicking latest news or latest update does nothing', 'Expected Result': 'Open up a tab with past news or patch updates', 'Actual Result': 'Nothing happens', 'Repeatable?': 'Yes', 'Blocker?': 'Yes', 'Test Owner': 'Jorge Enriquez'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be2677'), 'Test #': 1, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Tutorial', 'Test Case': 'Tutorial Does Not Load', 'Expected Result': 'Tutorial to pop up', 'Actual Result': 'Went to black screen and froze', 'Repeatable?': 'Yes', 'Blocker?': 'Yes', 'Test Owner': 'Anthony Daulo'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be2678'), 'Test #': 2, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Tutorial', 'Test Case': 'Skips Enemy AI Actions', 'Expected Result': 'Full animation of enemy actions plays out', 'Actual Result': 'Skips through animations and can only view aftermath of game actions', 'Repeatable?': 'Yes', 'Blocker?': 'No', 'Test Owner': 'Anthony Daulo'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be2679'), 'Test #': 3, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Tutorial', 'Test Case': 'Skipped turn without giving opportunity for game actions', 'Expected Result': "After enemy's turn ends to take control of game", 'Actual Result': 'Timer ticked down without givien opportunityi to play cards', 'Repeatable?': 'No', 'Blocker?': 'No', 'Test Owner': 'Anthony Daulo'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be267f'), 'Test #': 1, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'In game', 'Test Case': "design feature: When attack the user directly the health of the user can become unreadable due to the black font and the black background when gettign the user's health low", 'Expected Result': 'I expected to see the opponnets health throught the game', 'Actual Result': "I can't see my opponent's helath because the healthbar background(black was the same color as the text of their health", 'Repeatable?': 'yes', 'Blocker?': 'no', 'Test Owner': 'Mansoor Amza'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be2680'), 'Test #': 2, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Arena page', 'Test Case': "bug: After clicking arena, I can't go back to main page by clicking the back arrow", 'Expected Result': 'I expected to go back the main page', 'Actual Result': 'I am stuck on the arena page', 'Repeatable?': 'yes', 'Blocker?': 'yes', 'Test Owner': 'Mansoor Amza'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be2681'), 'Test #': 3, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Arena page', 'Test Case': "bug: I can't go to the home page after clicking the home button", 'Expected Result': 'I expected to go back to the home page after clicking the home button', 'Actual Result': 'I am stuck in the arena page', 'Repeatable?': 'yes', 'Blocker?': 'yes', 'Test Owner': 'Mansoor Amza'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be2682'), 'Test #': 1, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Game', 'Test Case': 'matches are very long', 'Expected Result': 'games take around 5 minutes', 'Actual Result': 'Games take around 10-15 minutes', 'Repeatable?': 'yes', 'Blocker?': 'no', 'Test Owner': 'Donald Cruz'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be2683'), 'Test #': 2, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Game', 'Test Case': 'First turn of the duel, standby phase does not automatically move to main phase 1', 'Expected Result': 'the game to automatically switch from standby phase to main phase 1', 'Actual Result': 'Game stays in standby phase', 'Repeatable?': 'yes', 'Blocker?': 'no', 'Test Owner': 'Donald Cruz'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be2684'), 'Test #': 3, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Main Page', 'Test Case': 'Switching from the 5HeadGames screen to the main page resets menu music', 'Expected Result': 'the music to stay playing', 'Actual Result': 'game resets the music when pressing the back button', 'Repeatable?': 'yes', 'Blocker?': 'no', 'Test Owner': 'Donald Cruz'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be2688'), 'Test #': 1, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Profile', 'Test Case': '"Player Frame", "Player Title", and "Player Banner" buttons not working', 'Expected Result': 'Corresponding pages should open allowing the user to customize their frame, title, and banner', 'Actual Result': 'nothing', 'Repeatable?': 'yes', 'Blocker?': 'no', 'Test Owner': 'Brandon Hakimi'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be2689'), 'Test #': 2, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Adventure', 'Test Case': 'Stuck in Adventure game mode', 'Expected Result': 'That the home button will bring me home, or the deck builder button would bring me to the deck building screen', 'Actual Result': 'nothing', 'Repeatable?': 'yes', 'Blocker?': 'yes (no way to exit this screen without login refresh)', 'Test Owner': 'Brandon Hakimi'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be268a'), 'Test #': 3, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Arena', 'Test Case': 'Custom name not showing up in Arena gameplay', 'Expected Result': '"Velocity" should be the name I see as that is what I set it to', 'Actual Result': 'Some random assortment of numbers and letters', 'Repeatable?': 'yes', 'Blocker?': 'no', 'Test Owner': 'Brandon Hakimi'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be268b'), 'Test #': 4, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Arena', 'Test Case': 'Game stuck, timer not moving and nothing happening. After about 2 minutes of nothing happening and the page being unresponsive the victory screen was displayed.', 'Expected Result': 'Not sure how big of an error this is if it even is one. I mean the timer stopped for a while with nothing happening so I assume the other party left a long time ago', 'Actual Result': 'Victory screen should be snappier. If other party leaves it shouldn’t take more than 30 seconds for the game to register and not just leave me hanging', 'Repeatable?': 'yes', 'Blocker?': 'yes (temporarily)', 'Test Owner': 'Brandon Hakimi'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be268f'), 'Test #': 1, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Game', 'Test Case': 'Bug: Activating card does not work', 'Expected Result': 'Void trap should apply damage', 'Actual Result': 'Action was chosen but no card effect occurs', 'Repeatable?': 'no', 'Blocker?': 'no', 'Test Owner': 'Paige Watanabe'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be2690'), 'Test #': 2, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Game', 'Test Case': 'Bug: Frozen turn', 'Expected Result': 'Game continues turn cycles normally', 'Actual Result': 'Attempting to activate card lead to game being softlocked; timer for opponent was stuck at 72 seconds', 'Repeatable?': 'no', 'Blocker?': 'yes', 'Test Owner': 'Paige Watanabe'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be2691'), 'Test #': 3, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'UI', 'Test Case': 'Bug: Clicking does not work on settings menu', 'Expected Result': 'Exit out of settings window', 'Actual Result': 'Button is clicked but nothing happens', 'Repeatable?': 'yes', 'Blocker?': 'no', 'Test Owner': 'Paige Watanabe'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be2694'), 'Test #': 3, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Login', 'Test Case': 'bug: game uses too much memory to open', 'Expected Result': 'game opens', 'Actual Result': 'error that I don’t have enough memory to open page after bar gets to 90%', 'Repeatable?': 'yes', 'Blocker?': 'yes', 'Test Owner': 'Rahi Misra'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be2696'), 'Test #': 1, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Landpage', 'Test Case': "Buttons aren't responsive when exiting friend screen", 'Expected Result': 'buttons to respond', 'Actual Result': "buttons don't respond", 'Repeatable?': 'yes', 'Blocker?': 'yes', 'Test Owner': 'Jean Hanna'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be2697'), 'Test #': 2, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Game audio settings', 'Test Case': "Master/Music Volume and Sound FX sliders don't change anything", 'Expected Result': 'to change volume', 'Actual Result': "doesn't change volume", 'Repeatable?': 'yes', 'Blocker?': 'yes', 'Test Owner': 'Jean Hanna'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be26a6'), 'Test #': 1, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Game', 'Test Case': 'Able to exit the deck building tutorial, got softlocked', 'Expected Result': 'Cannot exit the tutorial', 'Actual Result': 'Exited the tutorial with the prompts active', 'Repeatable?': 'yes', 'Blocker?': 'yes', 'Test Owner': 'Dawson Ford'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be26a7'), 'Test #': 2, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Game', 'Test Case': 'Every time I login, the game thinks I am a new palyer', 'Expected Result': 'Prompt stops showing up to play the tuorial', 'Actual Result': 'prompt keeps showing up', 'Repeatable?': 'yes', 'Blocker?': 'no', 'Test Owner': 'Dawson Ford'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be26a8'), 'Test #': 3, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Game', 'Test Case': 'Latncy jumped from 100 to over 1700 when joining and playing match', 'Expected Result': 'The latency stayed the same as shown in the menu of hte game (100)', 'Actual Result': 'Lantency skyrocketed', 'Repeatable?': 'yes', 'Blocker?': 'no', 'Test Owner': 'Dawson Ford'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be26ad'), 'Test #': 1, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'UI', 'Test Case': 'Leaderboard: information about user ranking does not display correctly, text writes over other text.', 'Expected Result': 'Readable text', 'Actual Result': 'Text not formatting correctly', 'Repeatable?': 'yes', 'Blocker?': 'no', 'Test Owner': 'Elizabeth Morgan'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be26ae'), 'Test #': 2, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Game', 'Test Case': 'Deck Building: when removing a card from a pre-existing deck, I cannot add new cards without exiting the deck building and returning.', 'Expected Result': 'Edit decks freely', 'Actual Result': 'Cannot add new cards, must re-enter deck building screen', 'Repeatable?': 'yes', 'Blocker?': 'no', 'Test Owner': 'Elizabeth Morgan'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be26af'), 'Test #': 3, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Game', 'Test Case': 'Cards: Some cards have a lot of text and the readability suffers due to the text shrinking. I recommend perhaps float text that enlarges the descriptions.', 'Expected Result': 'Readable text', 'Actual Result': 'Long descriptions shrink text and affect readability', 'Repeatable?': 'yes', 'Blocker?': 'no', 'Test Owner': 'Elizabeth Morgan'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be26b0'), 'Test #': 4, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Game', 'Test Case': 'Artwork: Chosen One card has artwork that is somewhat lacking compared to art in other cards, recommend renewing this artwork.', 'Expected Result': 'Quality of cards', 'Actual Result': 'Artwork is lacking', 'Repeatable?': 'yes', 'Blocker?': 'no', 'Test Owner': 'Elizabeth Morgan'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be26b1'), 'Test #': 5, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Game', 'Test Case': 'Artwork: The Yoshiko card had a description for “Good Boy”, but the name Yoshiko is a girl’s name.', 'Expected Result': 'Quality of cards', 'Actual Result': 'Translation error?', 'Repeatable?': 'yes', 'Blocker?': 'no', 'Test Owner': 'Elizabeth Morgan'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be26b2'), 'Test #': 7, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'UI', 'Test Case': 'Marketplace: does not show all cards, only the first page and depending on the setting used (Low to High, High to Low, etc) or by using the filter.', 'Expected Result': 'Easy access to all cards in marketplace.', 'Actual Result': 'Must search or specify desired cards instead of freely browsing list.', 'Repeatable?': 'yes', 'Blocker?': 'no', 'Test Owner': 'Elizabeth Morgan'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be26b3'), 'Test #': 8, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'UI', 'Test Case': 'Card Gallery, Marketplace: navigation arrows should should more than the page number at the bottom of the gallery. By only showing < 1 > implies there is only one page.', 'Expected Result': 'Understandable navigation', 'Actual Result': 'Missleading navigation', 'Repeatable?': 'yes', 'Blocker?': 'no', 'Test Owner': 'Elizabeth Morgan'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be26b4'), 'Test #': 19, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'UI', 'Test Case': 'Deck Builder: This page should show off NFTs currently for sale or for rent to promote sales during typical gameplay.', 'Expected Result': 'Awareness of cards for sale/rent', 'Actual Result': 'Basic cards shown only', 'Repeatable?': 'yes', 'Blocker?': 'no', 'Test Owner': 'Elizabeth Morgan'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be26b5'), 'Test #': 1, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Main Page', 'Test Case': 'Close Settings Box', 'Expected Result': 'Pressing X closes box', 'Actual Result': 'Nothing', 'Repeatable?': 'Yes', 'Blocker?': 'No', 'Test Owner': 'Jack Konyan'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be26b6'), 'Test #': 2, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Adventure', 'Test Case': 'Loads mission name', 'Expected Result': 'Mission name is shown', 'Actual Result': 'Generic Mission name', 'Repeatable?': 'Yes', 'Blocker?': 'No', 'Test Owner': 'Jack Konyan'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be26b7'), 'Test #': 3, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Adventure', 'Test Case': 'Mission objectives', 'Expected Result': 'Loads mission objectives', 'Actual Result': 'No objectives shown', 'Repeatable?': 'Yes', 'Blocker?': 'No', 'Test Owner': 'Jack Konyan'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be26b8'), 'Test #': 4, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Adventure', 'Test Case': 'Play Mission', 'Expected Result': 'Mission Starts', 'Actual Result': 'Mission does not start', 'Repeatable?': 'Yes', 'Blocker?': 'No', 'Test Owner': 'Jack Konyan'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be26b9'), 'Test #': 1, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Arena Player', 'Test Case': 'Ran as intended', 'Expected Result': 'Game concluded in a victory', 'Actual Result': 'Game played smoothly with no errors', 'Repeatable?': 'yes', 'Blocker?': 'no', 'Test Owner': 'Andrew Demirjian'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be26ba'), 'Test #': 2, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Arena AI', 'Test Case': 'Ran as intended', 'Expected Result': 'AI finished playing the game', 'Actual Result': 'AI played the game', 'Repeatable?': 'yes', 'Blocker?': 'No', 'Test Owner': 'Andrew Demirjian'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be26bb'), 'Test #': 3, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Arena AI', 'Test Case': 'Ran as intended', 'Expected Result': 'AI finished playing the game', 'Actual Result': 'AI played the game', 'Repeatable?': 'yes', 'Blocker?': 'no', 'Test Owner': 'Andrew Demirjian'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be26bc'), 'Test #': 0, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Game', 'Test Case': 'User Case: Blurred game elements & text towards edges of game screen during battle.', 'Expected Result': 'Be able to clearly see all elements & text anywhere on-screen.', 'Actual Result': 'There appears to be a strong blur effect implemented towards the edges of the screen during battle mode.', 'Repeatable?': 'Yes', 'Blocker?': 'No', 'Test Owner': 'Svarun Soda'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be26bd'), 'Test #': 1, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Game', 'Test Case': 'Bug: Infinite empty wait loop upon entering arena and connecting to an opponent.', 'Expected Result': 'Jump into battle vs. opponent upon clicking “Arena”.', 'Actual Result': 'Unable to get to the actual battle phase, suck in first loading phase without any elements on the screen.', 'Repeatable?': 'No', 'Blocker?': 'Yes', 'Test Owner': 'Svarun Soda'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be26be'), 'Test #': 2, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Login', 'Test Case': 'Bug: Always being asked to double-verify email before logging in.', 'Expected Result': 'Be automatically authenticated if logging in with same PC many times.', 'Actual Result': 'Asked to verify email twice upon every login, even if immediately consecutive.', 'Repeatable?': 'Yes', 'Blocker?': 'No', 'Test Owner': 'Svarun Soda'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be26bf'), 'Test #': 1, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Login', 'Test Case': 'Window Resize did not fit to vertical Window', 'Expected Result': 'Resize to vertical screen', 'Actual Result': 'Did not resize', 'Repeatable?': 'Yes', 'Blocker?': 'No', 'Test Owner': 'Javier Torres'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be26c0'), 'Test #': 2, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Main menu', 'Test Case': 'On main page I selected "settings" before I closed the Ultraman promotion and now I cant close the settings tab using the "X"', 'Expected Result': 'Able to close out the game using the "X" button on the top right corner of the window', 'Actual Result': 'Cannot close settings menu without hitting Cancel', 'Repeatable?': 'Yes', 'Blocker?': 'No', 'Test Owner': 'Javier Torres'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be26c1'), 'Test #': 3, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'Adventure Menu', 'Test Case': 'Clicking on anything does not work when I entered "Adventure" Mode, I cannot back out of this window either.', 'Expected Result': 'Working "Play" buttons, be able to back out of "Adventure Mode". Nothing happens.', 'Actual Result': 'Nothing happens aside from when you select a mission, a window pops up but when you try to "play" nothing happens.', 'Repeatable?': 'Yes', 'Blocker?': 'No', 'Test Owner': 'Javier Torres'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be26c2'), 'Test #': 0, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': '5HeadGames/Login/EndersGate/Login', 'Test Case': 'Ex user case: game did not log me in', 'Expected Result': 'Game launches properly after logging in from the 5 Head Games Launcher', 'Actual Result': "Receive the following error in a popup box : “screen.orientation.lock is not a function. (In ‘screen.orientation.lock(type)', 'screen.orientation.lock' is undefined)”", 'Repeatable?': 'Yes', 'Blocker?': 'Yes', 'Test Owner': 'Narek Karapetyan'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be26c3'), 'Test #': 1, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'EndersGate/MyPacks/Swap Your Collab pass/FAQ', 'Test Case': 'Ex bug: FAQ link takes me to FAQ', 'Expected Result': 'FAQ displayed on the screen', 'Actual Result': 'Receive the following error: “An error has occurred while switching chain, please try again.”', 'Repeatable?': 'Yes', 'Blocker?': 'No', 'Test Owner': 'Narek Karapetyan'}
# -------------------------
# {'_id': ObjectId('660ccd3ac0d474b140be26c4'), 'Test #': 2, 'Build #': datetime.datetime(2024, 3, 19, 0, 0), 'Category': 'EndersGate/Card Gallery', 'Test Case': 'Ex bug: My owned cards come up as 0 in my card gallery', 'Expected Result': 'I have a 1 under the cards I own', 'Actual Result': 'Cards show zero owned', 'Repeatable?': 'Yes', 'Blocker?': 'No', 'Test Owner': 'Narek Karapetyan'}
# -------------------------
# Reports on build date:  None
# First test case:  1
# Middle test case:  1
# Last test case:  3

# %%
from datetime import datetime
import pandas as pd
from pymongo import MongoClient

def clean_collections(collection1, collection2):
    bad_data_ids = set()

    # Clean collection1
    for document in collection1.find():
        if is_bad_data(document):
            bad_data_ids.add(document["_id"])

    # Clean collection2
    for document in collection2.find():
        if is_bad_data(document):
            bad_data_ids.add(document["_id"])

    # Remove bad data documents
    for bad_id in bad_data_ids:
        collection1.delete_one({"_id": bad_id})
        collection2.delete_one({"_id": bad_id})

# Function to validate and filter data (example implementation)
def is_bad_data(document):
    # Define a list of required fields
    required_fields = ["Test #", "Build #", "Category", "Test Case", "Expected Result", "Actual Result", "Repeatable?", "Blocker?", "Test Owner"]

    # Check if any required field is missing
    for field in required_fields:
        if field not in document:
            return True  # Document is bad if any required field is missing
    return False  # Document is not bad if all required fields are present

def list_entries_by_user(db, user_id):
    collection1 = db["Collection1"]
    collection2 = db["Collection2"]

    # Set to store unique entries
    unique_entries = set()

    # List entries for the specific user from both collections
    output = []
    for collection_name, collection in [("Collection1", collection1), ("Collection2", collection2)]:
        for document in collection.find({"Test Owner": user_id}):
            entry_str = ", ".join([f"{key}: {value}" for key, value in document.items()])
            if entry_str not in unique_entries:
                unique_entries.add(entry_str)
                output.append(entry_str + "\n-------------------------\n")  # Separator between documents

    # Count the number of unique entries
    count = len(unique_entries)
    
    return count, output


def count_blocker_and_repeater_bugs(db):
    collection1 = db["Collection1"]
    collection2 = db["Collection2"]

    # Count the number of blocker and repeater bugs
    blocker_count = 0
    repeater_count = 0
    for collection in [collection1, collection2]:
        for document in collection.find({}, {"_id": 0, "Blocker?": 1, "Repeatable?": 1}):
            if document.get("Blocker?") == "Yes":
                blocker_count += 1
            if document.get("Repeatable?") == "Yes":
                repeater_count += 1

    return blocker_count, repeater_count

def find_reports_on_build(db, build_date):
    collection1 = db["Collection1"]
    collection2 = db["Collection2"]

    # Convert input date to a datetime object
    formatted_build_date = datetime.strptime(build_date, "%m/%d/%Y").date()

    # Retrieve all reports on the specified build date from both collections (no duplicates)
    output = []
    for collection_name, collection in [("Collection1", collection1), ("Collection2", collection2)]:
        for document in collection.find():
            # Check if the "Build #" field is a datetime object and compare the date part
            if isinstance(document.get("Build #"), datetime) and document.get("Build #").date() == formatted_build_date:
                # Add the document to the output list
                output.append(str(document) + "\n-------------------------\n")  # Separator between documents

    return output

def get_first_middle_last_test_cases(db):
    collection2 = db["Collection2"]

    # Retrieve all test cases from collection 2
    test_cases = []
    for document in collection2.find({}, {"_id": 0, "Test #": 1}):
        test_cases.append(document["Test #"])

    # Find the first, middle, and last test cases
    first_test_case = test_cases[0]
    middle_test_case = test_cases[len(test_cases) // 2]  # Determine the middle test case
    last_test_case = test_cases[-1]

    return first_test_case, middle_test_case, last_test_case

def write_output_to_file(output, file_name):
    with open(file_name, "w") as file:
        file.writelines(output)

def main():
    # Connect to MongoDB
    client = MongoClient("mongodb://localhost:27017/")
    db = client["your_database"]
    collection1 = db["Collection1"]  # Adjust collection names as needed
    collection2 = db["Collection2"]

    # Clean collections
    clean_collections(collection1, collection2)

    # Read the Excel file and dropna to remove empty rows
    excel_file = "EG4-DBDump.xlsx"
    data = pd.read_excel(excel_file).dropna()

    # Insert data into MongoDB collection
    collection2.insert_many(data.to_dict('records'))
    print("Data inserted into MongoDB collection successfully.")
    
    userId = "Kevin Chaja"
    user_entries_count, user_entries_output = list_entries_by_user(db, userId)
    write_output_to_file(user_entries_output, f"{userId}_entries.txt")
    print("Entries for user", userId, ":", user_entries_count)

    blocker_count, repeater_count = count_blocker_and_repeater_bugs(db)
    with open("blockers.txt", "w") as file:
        file.write("Number of blocker bugs: " + str(blocker_count))
    print("Number of blocker bugs:", blocker_count)
    with open("repeaters.txt", "w") as file:
        file.write("Number of repeater bugs: " + str(repeater_count))
    print("Number of repeater bugs:", repeater_count)

    reports_on_build_output = find_reports_on_build(db, "3/19/2024")
    write_output_to_file(reports_on_build_output, "reports_on_build.txt")
    print("Reports on build date: ", "3/19/2024")

    first_test_case, middle_test_case, last_test_case = get_first_middle_last_test_cases(db)
    with open("test_cases.txt", "w") as file:
        file.write("First test case: " + str(first_test_case) + "\n")
        file.write("Middle test case: " + str(middle_test_case) + "\n")
        file.write("Last test case: " + str(last_test_case) + "\n")
    print("First test case: ", first_test_case)
    print("Middle test case: ", middle_test_case)
    print("Last test case: ", last_test_case)

    # Close MongoDB connection
    client.close()

if __name__ == "__main__":
    main()
# Out:
# Data inserted into MongoDB collection successfully.
# Entries for user Kevin Chaja : 44
# Number of blocker bugs: 342
# Number of repeater bugs: 592
# Reports on build date:  3/19/2024
# First test case:  1
# Middle test case:  1
# Last test case:  3

# %%
from datetime import datetime
import pandas as pd
from pymongo import MongoClient

def clean_collections(collection1, collection2):
    bad_data_ids = set()

    # Clean collection1
    for document in collection1.find():
        if is_bad_data(document):
            bad_data_ids.add(document["_id"])

    # Clean collection2
    for document in collection2.find():
        if is_bad_data(document):
            bad_data_ids.add(document["_id"])

    # Remove bad data documents
    for bad_id in bad_data_ids:
        collection1.delete_one({"_id": bad_id})
        collection2.delete_one({"_id": bad_id})

# Function to validate and filter data (example implementation)
def is_bad_data(document):
    # Define a list of required fields
    required_fields = ["Test #", "Build #", "Category", "Test Case", "Expected Result", "Actual Result", "Repeatable?", "Blocker?", "Test Owner"]

    # Check if any required field is missing
    for field in required_fields:
        if field not in document:
            return True  # Document is bad if any required field is missing
    return False  # Document is not bad if all required fields are present

def list_entries_by_user(db, user_id, csv_filename):
    collection1 = db["Collection1"]
    collection2 = db["Collection2"]

    # List entries for the specific user from both collections
    entries = []
    for collection_name, collection in [("Collection1", collection1), ("Collection2", collection2)]:
        for document in collection.find({"Test Owner": user_id}):
            entries.append(document)

    # Create a DataFrame from the entries
    df = pd.DataFrame(entries)

    # Export DataFrame to CSV
    df.to_csv(csv_filename, index=False)

    return len(entries)

def count_blocker_and_repeater_bugs(db, blocker_filename, repeater_filename):
    collection1 = db["Collection1"]
    collection2 = db["Collection2"]

    # Lists to store blocker and repeater documents
    blocker_documents = []
    repeater_documents = []

    # Find blocker and repeater bugs and store their documents
    for collection in [collection1, collection2]:
        for document in collection.find({}, {"_id": 0, "Blocker?": 1, "Repeatable?": 1}):
            if document.get("Blocker?") == "Yes":
                blocker_documents.append(document)
            if document.get("Repeatable?") == "Yes":
                repeater_documents.append(document)

    # Export blocker documents to a file
    with open(blocker_filename, "w") as f:
        for doc in blocker_documents:
            f.write(str(doc) + "\n")

    # Export repeater documents to a file
    with open(repeater_filename, "w") as f:
        for doc in repeater_documents:
            f.write(str(doc) + "\n")

    return len(blocker_documents), len(repeater_documents)


def find_reports_on_build(db, build_date):
    collection1 = db["Collection1"]
    collection2 = db["Collection2"]

    # Convert input date to a datetime object
    formatted_build_date = datetime.strptime(build_date, "%m/%d/%Y").date()

    # Retrieve all reports on the specified build date from both collections (no duplicates)
    output = []
    for collection_name, collection in [("Collection1", collection1), ("Collection2", collection2)]:
        for document in collection.find():
            # Check if the "Build #" field is a datetime object and compare the date part
            if isinstance(document.get("Build #"), datetime) and document.get("Build #").date() == formatted_build_date:
                # Add the document to the output list
                output.append(str(document) + "\n-------------------------\n")  # Separator between documents

    return output

def get_first_middle_last_test_cases(db):
    collection2 = db["Collection2"]

    # Retrieve all test cases from collection 2
    test_cases = []
    for document in collection2.find({}, {"_id": 0, "Test #": 1}):
        test_cases.append(document["Test #"])

    # Find the first, middle, and last test cases
    first_test_case = test_cases[0]
    middle_test_case = test_cases[len(test_cases) // 2]  # Determine the middle test case
    last_test_case = test_cases[-1]
    

    return first_test_case, middle_test_case, last_test_case

def write_output_to_file(output, file_name):
    with open(file_name, "w") as file:
        file.writelines(output)

def main():
    # Connect to MongoDB
    client = MongoClient("mongodb://localhost:27017/")
    db = client["your_database"]
    collection1 = db["Collection1"]  # Adjust collection names as needed
    collection2 = db["Collection2"]

    # Clean collections
    clean_collections(collection1, collection2)

    # Read the Excel file and dropna to remove empty rows
    excel_file = "EG4-DBDump.xlsx"
    data = pd.read_excel(excel_file).dropna()

    # Insert data into MongoDB collection
    collection2.insert_many(data.to_dict('records'))
    print("Data inserted into MongoDB collection successfully.")
    
    userId = "Omar Monge"
    csv_filename = userId + ".csv"
    user_entries_count = list_entries_by_user(db, userId, csv_filename)
    print(f"Entries for user {userId} exported to {csv_filename}. Total entries: {user_entries_count}")

    blocker_filename = "blocker_bugs.txt"
    repeater_filename = "repeater_bugs.txt"
    blocker_count, repeater_count = count_blocker_and_repeater_bugs(db, blocker_filename, repeater_filename)
    print("Number of blocker bugs:", blocker_count)
    print("Number of repeater bugs:", repeater_count)
    print(f"Blocker bugs exported to {blocker_filename}")
    print(f"Repeater bugs exported to {repeater_filename}")

    

    reports_on_build_output = find_reports_on_build(db, "3/19/2024")
    write_output_to_file(reports_on_build_output, "reports_on_build.txt")
    print("Reports on build date: ", "3/19/2024")

    first_test_case, middle_test_case, last_test_case = get_first_middle_last_test_cases(db)
    with open("test_cases.txt", "w") as file:
        file.write("First test case: " + str(first_test_case) + "\n")
        file.write("Middle test case: " + str(middle_test_case) + "\n")
        file.write("Last test case: " + str(last_test_case) + "\n")
    print("First test case: ", first_test_case)
    print("Middle test case: ", middle_test_case)
    print("Last test case: ", last_test_case)

    # Close MongoDB connection
    client.close()

if __name__ == "__main__":
    main()
# Out:
# Data inserted into MongoDB collection successfully.
# Entries for user Omar Monge exported to Omar Monge.csv. Total entries: 15
# Number of blocker bugs: 342
# Number of repeater bugs: 592
# Blocker bugs exported to blocker_bugs.txt
# Repeater bugs exported to repeater_bugs.txt
# Reports on build date:  3/19/2024
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[68], line 179
#     176     client.close()
#     178 if __name__ == "__main__":
# --> 179     main()
#
# Cell In[68], line 166, in main()
#     163 write_output_to_file(reports_on_build_output, "reports_on_build.txt")
#     164 print("Reports on build date: ", "3/19/2024")
# --> 166 first_test_case, middle_test_case, last_test_case = get_first_middle_last_test_cases(db)
#     167 with open("test_cases.txt", "w") as file:
#     168     file.write("First test case: " + str(first_test_case) + "\n")
#
# Cell In[68], line 112, in get_first_middle_last_test_cases(db)
#     110 last_test_case = test_cases[-1]
#     111 # Export documents to files
# --> 112 with open(first_filename, "w") as f:
#     113     f.write(str(first_test_case) + "\n")
#     115 with open(middle_filename, "w") as f:
#
# NameError: name 'first_filename' is not defined

# %%
from datetime import datetime
import pandas as pd
from pymongo import MongoClient

def clean_collections(collection1, collection2):
    bad_data_ids = set()

    # Clean collection1
    for document in collection1.find():
        if is_bad_data(document):
            bad_data_ids.add(document["_id"])

    # Clean collection2
    for document in collection2.find():
        if is_bad_data(document):
            bad_data_ids.add(document["_id"])

    # Remove bad data documents
    for bad_id in bad_data_ids:
        collection1.delete_one({"_id": bad_id})
        collection2.delete_one({"_id": bad_id})

# Function to validate and filter data (example implementation)
def is_bad_data(document):
    # Define a list of required fields
    required_fields = ["Test #", "Build #", "Category", "Test Case", "Expected Result", "Actual Result", "Repeatable?", "Blocker?", "Test Owner"]

    # Check if any required field is missing
    for field in required_fields:
        if field not in document:
            return True  # Document is bad if any required field is missing
    return False  # Document is not bad if all required fields are present

def list_entries_by_user(db, user_id, csv_filename):
    collection1 = db["Collection1"]
    collection2 = db["Collection2"]

    # List entries for the specific user from both collections
    entries = []
    for collection_name, collection in [("Collection1", collection1), ("Collection2", collection2)]:
        for document in collection.find({"Test Owner": user_id}):
            entries.append(document)

    # Create a DataFrame from the entries
    df = pd.DataFrame(entries)

    # Export DataFrame to CSV
    df.to_csv(csv_filename, index=False)

    return len(entries)

def count_blocker_and_repeater_bugs(db, blocker_filename, repeater_filename):
    collection1 = db["Collection1"]
    collection2 = db["Collection2"]

    # Initialize counters
    blocker_count = 0
    repeater_count = 0

    # Open files for writing documents
    with open(blocker_filename, "w") as blocker_file, open(repeater_filename, "w") as repeater_file:
        # Find and write documents for blocker bugs
        blocker_file.write("Blocker Bugs:\n\n")
        for collection in [collection1, collection2]:
            for document in collection.find({"Blocker?": "Yes"}):
                blocker_count += 1
                blocker_file.write(str(document) + "\n\n")

        # Find and write documents for repeater bugs
        repeater_file.write("Repeater Bugs:\n\n")
        for collection in [collection1, collection2]:
            for document in collection.find({"Repeatable?": "Yes"}):
                repeater_count += 1
                repeater_file.write(str(document) + "\n\n")

    return blocker_count, repeater_count


def find_reports_on_build(db, build_date):
    collection1 = db["Collection1"]
    collection2 = db["Collection2"]

    # Convert input date to a datetime object
    formatted_build_date = datetime.strptime(build_date, "%m/%d/%Y").date()

    # Retrieve all reports on the specified build date from both collections (no duplicates)
    output = []
    for collection_name, collection in [("Collection1", collection1), ("Collection2", collection2)]:
        for document in collection.find():
            # Check if the "Build #" field is a datetime object and compare the date part
            if isinstance(document.get("Build #"), datetime) and document.get("Build #").date() == formatted_build_date:
                # Add the document to the output list
                output.append(str(document) + "\n-------------------------\n")  # Separator between documents

    return output

def get_documents_for_test_cases(db):
    collection2 = db["Collection2"]

    # Retrieve all documents from collection 2
    documents = list(collection2.find())

    # Get indices for first, middle, and last documents
    first_index = 0
    middle_index = len(documents) // 2
    last_index = len(documents) - 1

    # Extract first, middle, and last documents
    first_document = documents[first_index]
    middle_document = documents[middle_index]
    last_document = documents[last_index]

    return first_document, middle_document, last_document

def write_output_to_file(output, file_name):
    with open(file_name, "w") as file:
        file.writelines(output)

def main():
    # Connect to MongoDB
    client = MongoClient("mongodb://localhost:27017/")
    db = client["your_database"]
    collection1 = db["Collection1"]  # Adjust collection names as needed
    collection2 = db["Collection2"]

    # Clean collections
    clean_collections(collection1, collection2)

    # Read the Excel file and dropna to remove empty rows
    excel_file = "EG4-DBDump.xlsx"
    data = pd.read_excel(excel_file).dropna()

    # Insert data into MongoDB collection
    collection2.insert_many(data.to_dict('records'))
    print("Data inserted into MongoDB collection successfully.")
    
    userId = "Omar Monge"
    csv_filename = userId + ".csv"
    user_entries_count = list_entries_by_user(db, userId, csv_filename)
    print(f"Entries for user {userId} exported to {csv_filename}. Total entries: {user_entries_count}")

    blocker_filename = "blocker_bugs.txt"
    repeater_filename = "repeater_bugs.txt"
    test_cases_filename = "firstMiddleLast.txt"
    
    blocker_count, repeater_count = count_blocker_and_repeater_bugs(db, blocker_filename, repeater_filename)
    print("Number of blocker bugs:", blocker_count)
    print("Number of repeater bugs:", repeater_count)
    print(f"Blocker bugs exported to {blocker_filename}")
    print(f"Repeater bugs exported to {repeater_filename}")

    

    reports_on_build_output = find_reports_on_build(db, "3/19/2024")
    write_output_to_file(reports_on_build_output, "reports_on_build.txt")
    print("Reports on build date: ", "3/19/2024")

    first_document, middle_document, last_document = get_documents_for_test_cases(db)

    # Write documents to file
    with open("test_cases.txt", "w") as f:
        f.write("First test case:\n")
        f.write(str(first_document) + "\n\n")
        f.write("Middle test case:\n")
        f.write(str(middle_document) + "\n\n")
        f.write("Last test case:\n")
        f.write(str(last_document) + "\n\n")

    # Close MongoDB connection
    client.close()

if __name__ == "__main__":
    main()
# Out:
# Data inserted into MongoDB collection successfully.
# Entries for user Omar Monge exported to Omar Monge.csv. Total entries: 17
# Number of blocker bugs: 171
# Number of repeater bugs: 296
# Blocker bugs exported to blocker_bugs.txt
# Repeater bugs exported to repeater_bugs.txt
# Reports on build date:  3/19/2024
